# %%
import asyncio
import time
import websockets
uri = "ws://localhost:8008/ws/1122"
async with websockets.connect(uri) as websocket:
    while True:
    #     test_message = '{"msg": "test", "data": "test"}'
    #     await websocket.send(test_message)
    #     print(f"Sent: {test_message}")
    #     time.sleep(10)
        try:
            test_message = '{"msg": "test", "data": "test"}'
            await websocket.send(test_message)
            print(f"Sent: {test_message}")
            await asyncio.sleep(10)
        except websockets.ConnectionClosed as e:
                print(f'Terminated', e)
# Out:
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# Sent: {"msg": "test", "data": "test"}
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[5], line 11
#       9     await websocket.send(test_message)
#      10     print(f"Sent: {test_message}")
# ---> 11     await asyncio.sleep(10)
#      12 except websockets.ConnectionClosed as e:
#      13         print(f'Terminated', e)
#
# File c:\Users\Acer\miniconda3\envs\comprog_enc\lib\asyncio\tasks.py:659, in sleep(delay, result, loop)
#     655 h = loop.call_later(delay,
#     656                     futures._set_result_unless_cancelled,
#     657                     future, result)
#     658 try:
# --> 659     return await future
#     660 finally:
#     661     h.cancel()
#
# CancelledError:
